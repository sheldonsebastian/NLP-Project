# %%
# %reload_ext nb_black

# %%
import warnings

warnings.filterwarnings("ignore")

import pandas as pd

pd.set_option("max_row", 100000)

# used to evaluate model
from sklearn_crfsuite import metrics

# to set random seed
import numpy as np

np.random.seed(42)

import math

# %%
data = pd.read_csv(
    "../1 Scraping Data and Annotating Data/tagged_data.csv", index_col=0
)

# %%
agg_func = lambda s: [
    (w, p, t)
    for w, p, t in zip(
        s["word"].values.tolist(), s["pos"].values.tolist(), s["tag"].values.tolist()
    )
]

# %%
grouped = data.groupby("sentence#").apply(agg_func)

# %%
sentences = [s for s in grouped]

# %%
def sent2labels(sent):
    """Retrieve all the labels from sentences which are lists containing (w, p, t)"""
    return [label for token, postag, label in sent]

# %%
y = [sent2labels(s) for s in sentences]

# %%
# split into train and test
boundary = math.ceil(len(y) * 0.8)

# %%
# test data
y_test = y[boundary:]

# %%
#################################################
# Dependency parser
###################################################

# Import modules
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

# %%
# Locate validation set from sentence#212 onward (ID:212 to ID:263)
parse_data = data.iloc[2770:3445]

# Inspect the dataset
parse_data.head()
# Out:
#       sentence#    word pos        tag
# 2770      212.0   Spray  NN   U-Action
# 2771      212.0  baking  NN  B-Utensil
# 2772      212.0   sheet  NN  L-Utensil
# 2773      212.0    with  IN          O
# 2774      212.0     non  JJ  B-Utensil

# %%
# Set the sentenceID as index for merging ID:212 to ID:263
parse_data.set_index("sentence#", inplace=True)
parse_data.head()
# Out:
#              word pos        tag
# sentence#
# 212.0       Spray  NN   U-Action
# 212.0      baking  NN  B-Utensil
# 212.0       sheet  NN  L-Utensil
# 212.0        with  IN          O
# 212.0         non  JJ  B-Utensil

# %%
# Merge the words back to its orginal form by sentence ID
combined_sentence = (
    parse_data.groupby(["sentence#"])["word"]
    .apply(lambda x: " ".join(x.astype(str)))
    .reset_index()
)
pd.set_option("max_colwidth", 200)
combined_sentence.head()
# Out:
#    sentence#  \
# 0      212.0
# 1      213.0
# 2      214.0
# 3      215.0
# 4      216.0
#
#                                                                                                                                                     word
# 0                                                                                                            Spray baking sheet with non - stick spray .
# 1                                                                                                                    Spread potatoes onto baking sheet .
# 2  Bake for 15 minutes ; toss and turn ; bake for five minutes ; add herbs and toss ; bake a final five minutes until the potatoes are brown and crisp .
# 3                                                                                                                                    Serve immediately .
# 4                                                                  In 1/4 cup butter , saute carrots , onion , celery and broccoli stems for 5 minutes .

# %%
# Convert the dataframe to the nested list
combined_sentences_list = combined_sentence.reset_index()[
    ["sentence#", "word"]
].values.tolist()
for item in combined_sentences_list:
    print(item[1])
# Out:
# Spray baking sheet with non - stick spray .
# Spread potatoes onto baking sheet .
# Bake for 15 minutes ; toss and turn ; bake for five minutes ; add herbs and toss ; bake a final five minutes until the potatoes are brown and crisp .
# Serve immediately .
# In 1/4 cup butter , saute carrots , onion , celery and broccoli stems for 5 minutes .
# Add thyme , oregano and basil ; saute 5 minutes more .
# Add wine and deglaze pan .
# Add hot chicken stock and reduce by one - third .
# Add Worcestershire sauce , Tabasco , smoked chicken , beans and broccoli florets ; simmer 5 minutes .
# Add cream , simmer 5 minutes more and season to taste ( thicken with cornstarch if desired ) .
# Drop in remaining butter , piece by piece , stirring until melted and serve immediately .
# Smoked Chicken : On a covered grill , slightly smoke boneless chicken , cooking to medium rare ( about 30 minutes ) .
# Chef Meskan uses applewood chips and does not allow the grill to become too hot .
# Preheat oven to 350 degrees .
# Grease 13 x 9 baking pan .
# Cool completely on wire rack and cut into squares .
# In a large bowl , whisk together butter , sugar and vanilla .
# Add eggs and stir until well combined .
# Combine dry ingredients and blend well with wet ingredients .
# Reserve 2 cups of batter and set aside .
# Spread remaining batter in prepared pan .
# Arrange Peppermint Patties in a single layer over batter , about 1/2 inch apart .
# Carefully spread reserved 2 cups of batter on top .
# Bake for 50- 55 minutes or until brownies begin to pull away from sides of pan .
# Heat oven to 375 degrees .
# Brown ground beef and onion over medium heat ; drain .
# Stir in tomato sauce , taco or other sauce , salt , pepper , Tabasco , chiles , and cornmeal , adjusting for"hot " taste preference and desired thickness .
# Stir in more cornmeal , if desired .
# Stir in corn and olives .
# Transfer mixture to casserole dish ; cover and bake for 30 to 40 minutes , or until bubbly and heated through .
# Top with cheese immediately on removing from oven so cheese melts .
# Garnish with corn chips just before serving to keep them crisp .
# Serve with a cool fresh vegetable such as cucumber slices , avocado , or lettuce leaves , if desired .
# Cream the butter with the dressing mix ; spread evenly on the bread halves .
# Place under the broiler for 2 - 3 minutes , until golden and the butter begins to seep and bubble .
# Serve hot .
# In bowl , mix dry ingredients .
# Add venison and mix well .
# Do not overcook .
# Turn burner off and leave burgers in the pan while you put condiments on your hamburger bun .
# If cooking thawed burgers , cook about 2 - 3 minutes per side .
# Add liquid ingredients and mix well with a fork , until bread crumbs are barely noticeable .
# On plastic wrap , form into 8 ( 4 ounce ) patties , making them round and very flat-- like a fast - food burger .
# They can be cooked immediately , but I prefer to freeze them first .
# Place them on a large cookie sheet and freeze them several hours .
# Remove from freezer and place waxed paper between each burger as you stack them .
# I stack them in 2 1-quart freezer zip - lock bags .
# Preheat cast iron skillet to very hot .
# Cook frozen burgers until they are slightly charred on one side ( about 3 - 4 minutes ) and then turn and cook until the other side is slightly charred and burgers are medium - well .
# Mix all the ingredients using a blender .
# Pour into popsicle molds .
# Freeze and enjoy !

# %%
# Print(combined_sentence_list)
dp_picked_sent = []
not_dp_picked_sent = []

for sentence in combined_sentences_list:
    ind_sentences = sentence[1]
    doc = nlp(ind_sentences)
    for token in doc:
        if token.pos_ == "VERB":
            # print(int(sentence[0]), " ".join([token.dep_ for token in doc]))
            dep_parser = " ".join([token.dep_ for token in doc])
            dp_picked_sent.append((int(sentence[0]), dep_parser))

        else:
            non_dep_picked_sent = []
        # dp_picked_sent.append((int(sentence[0]), dep_parser))
        # if token.dep_ == "ROOT" or token.dep_ == "conj" or token.dep_ == "nmod" or token.dep_ == "advcl":
        # print(doc, "---->>>")

# %%
# Print(combined_sentence_list)
dp_picked_sent = []

for sentence in combined_sentences_list:
    ind_sentences = sentence[1]
    doc = nlp(ind_sentences)
    for token in doc:
        dep_parser = " ".join([token.dep_ for token in doc])
        dp_picked_sent.append((int(sentence[0]), dep_parser))
        #############################
        # Code for locate the ACTION words
        #############################
        # if token.pos_ == "VERB":
        # if token.dep_ == "ROOT" or token.dep_ == "conj":
        # print(doc, "---->>>", token.text, token.pos_, token.dep_)
        #############################
        # Code End
        #############################

        # if token.pos_ == "VERB":
        # print(int(sentence[0]), " ".join([token.dep_ for token in doc]))
        # dep_parser = " ".join([token.dep_ for token in doc])
    # dp_picked_sent.append((int(sentence[0]), dep_parser))

    # dp_picked_sent.append((int(sentence[0]), dep_parser))
    # if token.dep_ == "ROOT" or token.dep_ == "conj" or token.dep_ == "nmod" or token.dep_ == "advcl":
    # print(doc, "---->>>")

# %%
# Check the sentence with its ID
dp_picked_sent
# Out:
# [(212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (213, 'compound ROOT prep compound pobj punct'),
#  (213, 'compound ROOT prep compound pobj punct'),
#  (213, 'compound ROOT prep compound pobj punct'),
#  (213, 'compound ROOT prep compound pobj punct'),
#  (213, 'compound ROOT prep compound pobj punct'),
#  (213, 'compound ROOT prep compound pobj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (215, 'ROOT advmod punct'),
#  (215, 'ROOT advmod punct'),
#  (215, 'ROOT advmod punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (218, 'ROOT dobj cc compound conj punct'),
#  (218, 'ROOT dobj cc compound conj punct'),
#  (218, 'ROOT dobj cc compound conj punct'),
#  (218, 'ROOT dobj cc compound conj punct'),
#  (218, 'ROOT dobj cc compound conj punct'),
#  (218, 'ROOT dobj cc compound conj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (225, 'nsubj ROOT prep nummod pobj punct'),
#  (225, 'nsubj ROOT prep nummod pobj punct'),
#  (225, 'nsubj ROOT prep nummod pobj punct'),
#  (225, 'nsubj ROOT prep nummod pobj punct'),
#  (225, 'nsubj ROOT prep nummod pobj punct'),
#  (225, 'nsubj ROOT prep nummod pobj punct'),
#  (226, 'nmod nummod punct nummod compound ROOT punct'),
#  (226, 'nmod nummod punct nummod compound ROOT punct'),
#  (226, 'nmod nummod punct nummod compound ROOT punct'),
#  (226, 'nmod nummod punct nummod compound ROOT punct'),
#  (226, 'nmod nummod punct nummod compound ROOT punct'),
#  (226, 'nmod nummod punct nummod compound ROOT punct'),
#  (226, 'nmod nummod punct nummod compound ROOT punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (232, 'ROOT amod dobj prep amod pobj punct'),
#  (232, 'ROOT amod dobj prep amod pobj punct'),
#  (232, 'ROOT amod dobj prep amod pobj punct'),
#  (232, 'ROOT amod dobj prep amod pobj punct'),
#  (232, 'ROOT amod dobj prep amod pobj punct'),
#  (232, 'ROOT amod dobj prep amod pobj punct'),
#  (232, 'ROOT amod dobj prep amod pobj punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (236, 'nsubj ROOT prep nummod pobj punct'),
#  (236, 'nsubj ROOT prep nummod pobj punct'),
#  (236, 'nsubj ROOT prep nummod pobj punct'),
#  (236, 'nsubj ROOT prep nummod pobj punct'),
#  (236, 'nsubj ROOT prep nummod pobj punct'),
#  (236, 'nsubj ROOT prep nummod pobj punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (240, 'ROOT prep pobj cc conj punct'),
#  (240, 'ROOT prep pobj cc conj punct'),
#  (240, 'ROOT prep pobj cc conj punct'),
#  (240, 'ROOT prep pobj cc conj punct'),
#  (240, 'ROOT prep pobj cc conj punct'),
#  (240, 'ROOT prep pobj cc conj punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (246,
# ...
#  (254,
#   'prep amod pobj punct ROOT prep nummod punct nummod appos punct pobj punct advcl nsubj ccomp cc advmod conj prep det amod punct compound pobj punct'),
#  (254,
#   'prep amod pobj punct ROOT prep nummod punct nummod appos punct pobj punct advcl nsubj ccomp cc advmod conj prep det amod punct compound pobj punct'),
#  (254,
#   'prep amod pobj punct ROOT prep nummod punct nummod appos punct pobj punct advcl nsubj ccomp cc advmod conj prep det amod punct compound pobj punct'),
#  (254,
#   'prep amod pobj punct ROOT prep nummod punct nummod appos punct pobj punct advcl nsubj ccomp cc advmod conj prep det amod punct compound pobj punct'),
#  (254,
#   'prep amod pobj punct ROOT prep nummod punct nummod appos punct pobj punct advcl nsubj ccomp cc advmod conj prep det amod punct compound pobj punct'),
#  (254,
#   'prep amod pobj punct ROOT prep nummod punct nummod appos punct pobj punct advcl nsubj ccomp cc advmod conj prep det amod punct compound pobj punct'),
#  (254,
#   'prep amod pobj punct ROOT prep nummod punct nummod appos punct pobj punct advcl nsubj ccomp cc advmod conj prep det amod punct compound pobj punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (262, 'ROOT prep compound pobj punct'),
#  (262, 'ROOT prep compound pobj punct'),
#  (262, 'ROOT prep compound pobj punct'),
#  (262, 'ROOT prep compound pobj punct'),
#  (262, 'ROOT prep compound pobj punct'),
#  (263, 'ROOT cc conj punct'),
#  (263, 'ROOT cc conj punct'),
#  (263, 'ROOT cc conj punct'),
#  (263, 'ROOT cc conj punct')]

# %%
set((int(sentence[0]), dep_parser))
# Out:
# {263, 'ROOT cc conj punct'}

# %%
# Print out the result
print(
    "Total # of sentences:",
    len(combined_sentences_list),
    "\n# of Dependency Parser PICKED sentences:",
    len(set(dp_picked_sent)),
)
# Out:
# Total # of sentences: 52
# # of Dependency Parser PICKED sentences: 52

# %%
# Reform the sentence data

# Remove duplicates
dp_picked_a = set(list(dp_picked_sent))
dp_picked_new = list(dp_picked_a)

# Sort the order by ID
dp_picked_final = sorted(dp_picked_new)
dp_picked_final
# Out:
# [(212, 'compound compound ROOT prep dep dep amod pobj punct'),
#  (213, 'compound ROOT prep compound pobj punct'),
#  (214,
#   'advcl prep nummod pobj punct conj cc conj punct ROOT prep nummod pobj punct conj dobj cc conj punct conj det amod nummod dobj mark det nsubj advcl acomp cc conj punct'),
#  (215, 'ROOT advmod punct'),
#  (216,
#   'prep nummod compound nsubj punct compound conj punct conj punct conj cc conj ROOT prep nummod pobj punct'),
#  (217, 'ROOT dobj punct conj cc conj punct conj nummod npadvmod advmod punct'),
#  (218, 'ROOT dobj cc compound conj punct'),
#  (219, 'ROOT amod compound dobj cc conj prep nummod punct pobj punct'),
#  (220,
#   'ROOT compound dobj punct appos punct amod conj punct conj cc compound conj punct appos nummod appos punct'),
#  (221,
#   'compound nsubj punct appos nummod npadvmod advmod cc conj aux relcl punct ROOT prep pobj mark advcl punct punct'),
#  (222,
#   'ROOT prep amod pobj punct conj prep pobj punct acl mark advcl cc conj advmod punct'),
#  (223,
#   'amod ROOT punct prep det amod pobj punct advmod compound compound pobj punct pcomp prep pobj amod punct advmod nummod npadvmod punct punct'),
#  (224,
#   'compound nsubj ROOT amod dobj cc aux neg conj det nsubj aux ccomp advmod acomp punct'),
#  (225, 'nsubj ROOT prep nummod pobj punct'),
#  (226, 'nmod nummod punct nummod compound ROOT punct'),
#  (227, 'ROOT advmod prep compound pobj cc conj prep pobj punct'),
#  (228, 'ROOT det amod pobj punct nmod advmod pobj punct conj cc conj punct'),
#  (229, 'ROOT dobj cc conj mark advmod advcl punct'),
#  (230, 'ROOT amod dobj cc conj advmod prep amod pobj punct'),
#  (231, 'ROOT nummod dobj prep pobj cc conj advmod punct'),
#  (232, 'ROOT amod dobj prep amod pobj punct'),
#  (233,
#   'amod compound ROOT prep det amod pobj prep pobj punct advmod nummod npadvmod advmod punct'),
#  (234, 'advmod nsubj ROOT nummod dobj prep pobj prep pobj punct'),
#  (235,
#   'ROOT prep nmod nummod pobj cc mark nsubj advcl aux xcomp advmod prep pobj prep pobj punct'),
#  (236, 'nsubj ROOT prep nummod pobj punct'),
#  (237, 'amod compound dep cc conj prep amod pobj punct ROOT punct'),
#  (238,
#   'ROOT prep compound pobj punct conj cc amod conj punct conj punct conj punct conj punct conj punct cc conj punct conj amod punct compound dobj cc amod conj punct'),
#  (239, 'ROOT prep amod pobj punct mark advcl punct'),
#  (240, 'ROOT prep pobj cc conj punct'),
#  (241,
#   'compound ROOT prep compound pobj punct conj cc conj prep quantmod quantmod nummod pobj punct cc conj pcomp cc conj advmod punct'),
#  (242,
#   'ROOT prep pobj advmod prep pcomp prep compound case compound pobj punct'),
#  (243, 'ROOT prep compound pobj advmod prep pcomp aux xcomp dobj oprd punct'),
#  (244,
#   'ROOT prep det amod amod pobj amod prep compound pobj punct conj punct cc conj dobj punct mark advcl punct'),
#  (245,
#   'advcl det dobj prep det amod pobj punct ROOT advmod prep det compound pobj punct'),
#  (246,
#   'nsubj prep det pobj prep nummod punct nummod pobj punct prep pobj cc det nsubj ROOT prep pobj cc conj punct'),
#  (247, 'ROOT advmod punct'),
#  (248, 'ROOT pobj punct nmod amod pobj punct'),
#  (249, 'ROOT dobj cc conj advmod punct'),
#  (250, 'aux neg ROOT punct'),
#  (251,
#   'ROOT dobj prt cc conj dobj prep det pobj mark nsubj advcl dobj prep poss compound pobj punct'),
#  (252,
#   'mark advcl amod dobj punct ROOT advmod nummod punct prep dobj prep pobj punct'),
#  (253,
#   'ROOT amod dobj cc conj advmod prep det pobj punct mark compound nsubj advcl advmod acomp punct'),
#  (254,
#   'prep amod pobj punct ROOT prep nummod punct nummod appos punct pobj punct advcl nsubj ccomp cc advmod conj prep det amod punct compound pobj punct'),
#  (255,
#   'nsubjpass aux auxpass ROOT advmod punct cc nsubj conj aux xcomp dobj advmod punct'),
#  (256,
#   'ROOT dobj prep det amod compound pobj cc conj dobj amod npadvmod punct'),
#  (257,
#   'ROOT prep pobj cc conj amod dobj prep det pobj mark nsubj advcl dobj punct'),
#  (258,
#   'nsubj ROOT dobj prep nummod nummod compound compound punct compound pobj punct'),
#  (259, 'nsubj ROOT compound dobj prep advmod pobj punct'),
#  (260,
#   'ROOT amod dobj mark nsubjpass auxpass advmod advcl prep nummod pobj punct quantmod quantmod punct nummod appos punct cc advmod conj cc conj mark det amod nsubjpass auxpass advmod advcl cc nsubj conj amod punct acomp punct'),
#  (261, 'ROOT predet det dobj advcl det dobj punct'),
#  (262, 'ROOT prep compound pobj punct'),
#  (263, 'ROOT cc conj punct')]

# %%
for i in dp_picked_final:
    bb = list(i)

# %%
def convert(lst):
    return [i for item in lst for i in item.split()]

# %%
doc
# Out:
# Freeze and enjoy !

# %%
# Replace the dp parse with project tags

# tages = [("ROOT", "conj")]
# o_targe = []

dep_list = []
for i in dp_picked_final:
    p1 = i[1].split()
    p2 = map(
        lambda x: x
        if x == "ROOT" or x == "conj"  # or x == "nmod" or x == "acl" or x == "pcomp"
        else "O",
        p1,
    )
    new = map(lambda x: x if x == "O" else "U-Action", p2)
    dep_list.append((int(i[0]), list(new)))

dep_list
# Out:
# [(212, ['O', 'O', 'U-Action', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (213, ['O', 'U-Action', 'O', 'O', 'O', 'O']),
#  (214,
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O']),
#  (215, ['U-Action', 'O', 'O']),
#  (216,
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (217,
#   ['U-Action',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (218, ['U-Action', 'O', 'O', 'O', 'U-Action', 'O']),
#  (219, ['U-Action', 'O', 'O', 'O', 'O', 'U-Action', 'O', 'O', 'O', 'O', 'O']),
#  (220,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (221,
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (222,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O']),
#  (223,
#   ['O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (224,
#   ['O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (225, ['O', 'U-Action', 'O', 'O', 'O', 'O']),
#  (226, ['O', 'O', 'O', 'O', 'O', 'U-Action', 'O']),
#  (227, ['U-Action', 'O', 'O', 'O', 'O', 'O', 'U-Action', 'O', 'O', 'O']),
#  (228,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O']),
#  (229, ['U-Action', 'O', 'O', 'U-Action', 'O', 'O', 'O', 'O']),
#  (230, ['U-Action', 'O', 'O', 'O', 'U-Action', 'O', 'O', 'O', 'O', 'O']),
#  (231, ['U-Action', 'O', 'O', 'O', 'O', 'O', 'U-Action', 'O', 'O']),
#  (232, ['U-Action', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (233,
#   ['O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (234, ['O', 'O', 'U-Action', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (235,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (236, ['O', 'U-Action', 'O', 'O', 'O', 'O']),
#  (237, ['O', 'O', 'O', 'O', 'U-Action', 'O', 'O', 'O', 'O', 'U-Action', 'O']),
#  (238,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O']),
#  (239, ['U-Action', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (240, ['U-Action', 'O', 'O', 'O', 'U-Action', 'O']),
#  (241,
#   ['O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O']),
#  (242, ['U-Action', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (243, ['U-Action', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (244,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (245,
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (246,
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O']),
#  (247, ['U-Action', 'O', 'O']),
#  (248, ['U-Action', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (249, ['U-Action', 'O', 'O', 'U-Action', 'O', 'O']),
#  (250, ['O', 'O', 'U-Action', 'O']),
#  (251,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (252,
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (253,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (254,
#   ['O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (255,
#   ['O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (256,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (257,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (258, ['O', 'U-Action', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (259, ['O', 'U-Action', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (260,
#   ['U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'U-Action',
#    'O',
#    'O',
#    'O',
#    'O']),
#  (261, ['U-Action', 'O', 'O', 'O', 'O', 'O', 'O', 'O']),
#  (262, ['U-Action', 'O', 'O', 'O', 'O']),
#  (263, ['U-Action', 'O', 'U-Action', 'O'])]

# %%
# Assign modified tagged sentence to y_depend_output
y_depend_output = []
for i in dep_list:
    y_depend_output.append(i[1])

# %%
# Display the result of DP parse
print(
    metrics.flat_classification_report(
        y_test, y_depend_output, labels=["U-Action"], digits=3
    )
)
# Out:
#               precision    recall  f1-score   support
#
#     U-Action      0.523     0.695     0.597        82
#
#    micro avg      0.523     0.695     0.597        82
#    macro avg      0.523     0.695     0.597        82
# weighted avg      0.523     0.695     0.597        82

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("Add butter to a saucepan and cover with lid")

displacy.render(
    doc, style="dep", jupyter=True,
)
print(doc.to_json())
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="66d5f80740f34a518145bd1121c1a0b2-0" class="displacy" width="1625" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Add</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">butter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">saucepan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">cover</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">lid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66d5f80740f34a518145bd1121c1a0b2-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66d5f80740f34a518145bd1121c1a0b2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66d5f80740f34a518145bd1121c1a0b2-0-1" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66d5f80740f34a518145bd1121c1a0b2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,354.0 L398.0,342.0 382.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66d5f80740f34a518145bd1121c1a0b2-0-2" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66d5f80740f34a518145bd1121c1a0b2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66d5f80740f34a518145bd1121c1a0b2-0-3" stroke-width="2px" d="M420,352.0 C420,177.0 740.0,177.0 740.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66d5f80740f34a518145bd1121c1a0b2-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,354.0 L748.0,342.0 732.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66d5f80740f34a518145bd1121c1a0b2-0-4" stroke-width="2px" d="M70,352.0 C70,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66d5f80740f34a518145bd1121c1a0b2-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,354.0 L928.0,342.0 912.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66d5f80740f34a518145bd1121c1a0b2-0-5" stroke-width="2px" d="M70,352.0 C70,2.0 1100.0,2.0 1100.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66d5f80740f34a518145bd1121c1a0b2-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,354.0 L1108.0,342.0 1092.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66d5f80740f34a518145bd1121c1a0b2-0-6" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66d5f80740f34a518145bd1121c1a0b2-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1260.0,354.0 L1268.0,342.0 1252.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66d5f80740f34a518145bd1121c1a0b2-0-7" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66d5f80740f34a518145bd1121c1a0b2-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1435.0,354.0 L1443.0,342.0 1427.0,342.0" fill="currentColor"/>
# </g>
# </svg>
# {'text': 'Add butter to a saucepan and cover with lid', 'ents': [], 'sents': [{'start': 0, 'end': 43}], 'tokens': [{'id': 0, 'start': 0, 'end': 3, 'pos': 'VERB', 'tag': 'VB', 'dep': 'ROOT', 'head': 0}, {'id': 1, 'start': 4, 'end': 10, 'pos': 'NOUN', 'tag': 'NN', 'dep': 'dobj', 'head': 0}, {'id': 2, 'start': 11, 'end': 13, 'pos': 'ADP', 'tag': 'IN', 'dep': 'prep', 'head': 0}, {'id': 3, 'start': 14, 'end': 15, 'pos': 'DET', 'tag': 'DT', 'dep': 'det', 'head': 4}, {'id': 4, 'start': 16, 'end': 24, 'pos': 'NOUN', 'tag': 'NN', 'dep': 'pobj', 'head': 2}, {'id': 5, 'start': 25, 'end': 28, 'pos': 'CCONJ', 'tag': 'CC', 'dep': 'cc', 'head': 0}, {'id': 6, 'start': 29, 'end': 34, 'pos': 'VERB', 'tag': 'VB', 'dep': 'conj', 'head': 0}, {'id': 7, 'start': 35, 'end': 39, 'pos': 'ADP', 'tag': 'IN', 'dep': 'prep', 'head': 6}, {'id': 8, 'start': 40, 'end': 43, 'pos': 'NOUN', 'tag': 'NN', 'dep': 'pobj', 'head': 7}]}

# %%
##########################
# The end
##########################
